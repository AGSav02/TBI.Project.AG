# %%
import matplotlib.pyploy as plt
import pandas as pd
import numpy as np

data = np.genfromtxt('/scr/velara/bioinf2/TBI.Project.AG/master_folder_z1.tsv', delimiter='\t', header = None, names = ['seq', 'mfe', 'z_score'])
