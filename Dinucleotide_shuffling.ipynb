# %%
from Bio import SeqIO
import random
import RNA
import statistics

Rna_file = SeqIO.read("/home/mescalin/bioinf2/Downloads/12q22_BAC_RPCI11-256L6.fasta", "fasta")
print(Rna_file)

sequence = str(Rna_file.seq)

def dishuff(seq):
    next_bases = {}
    for i in range(len(seq) -1):
        a, b = seq[i], seq[i + 1]
        if a not in next_bases:
            next_bases[a] = []
        next_bases[a].append(b)

    for a in next_bases:
        random.shuffle(next_bases[a])

    start = random.choice(list(next_bases.keys()))
    shuffled = [start]

    for _ in range(len(seq) - 1):
        a = shuffled[-1]
        if a not in next_bases or not next_bases[a]:
            remaining = [k for k, v in next_bases.items() if v]
            if not remaining:
                break
            a = random.choice(remaining)
            shuffled.append(a)
        b = next_bases[a].pop()
        shuffled.append(b)

    return ''.join(shuffled)

n = 299
shuffled_list = [sequence] + [dishuff(sequence) for _ in range(n)]
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 6
#       3 import RNA
#       4 import statistics
# ----> 6 Rna_file = SeqIO.read("/home/mescalin/bioinf2/Downloads/12q22_BAC_RPCI11-256L6.fasta", "fasta")
#       7 print(Rna_file)
#       9 sequence = str(Rna_file.seq)
#
# File /usr/lib64/python3.13/site-packages/Bio/SeqIO/__init__.py:687, in read(handle, format, alphabet)
#     685         pass
#     686 else:
# --> 687     with parse(handle, format, alphabet) as records:
#     688         try:
#     689             record = next(records)
#
# File /usr/lib64/python3.13/site-packages/Bio/SeqIO/__init__.py:626, in parse(handle, format, alphabet)
#     624 iterator_generator = _FormatToIterator.get(format)
#     625 if iterator_generator:
# --> 626     return iterator_generator(handle)
#     627 if format in AlignIO._FormatToIterator:
#     628     # Use Bio.AlignIO to read in the alignments
#     629     return (r for alignment in AlignIO.parse(handle, format) for r in alignment)
#
# File /usr/lib64/python3.13/site-packages/Bio/SeqIO/FastaIO.py:196, in FastaIterator.__init__(self, source, alphabet)
#     194 if alphabet is not None:
#     195     raise ValueError("The alphabet argument is no longer supported")
# --> 196 super().__init__(source, fmt="Fasta")
#     197 try:
#     198     line = next(self.stream)
#
# File /usr/lib64/python3.13/site-packages/Bio/SeqIO/Interfaces.py:81, in SequenceIterator.__init__(self, source, alphabet, fmt)
#      79 if isinstance(source, _PathLikeTypes):
#      80     mode = modes[0]
# ---> 81     self.stream = open(source, "r" + mode)
#      82 else:
#      83     value = source.read(0)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/mescalin/bioinf2/Downloads/12q22_BAC_RPCI11-256L6.fasta'

# %%
import csv

with open("12q22_BAC_RPCI11-256L6_shuffled.csv", 'w', newline='') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(["ID", "Sequence", "Structure", "MFE"]) 

    for i in range(0, 300):
        seq = shuffled_list[i]
        fc = RNA.fold_compound(seq, md)     
        structure, mfe = fc.mfe() 
        mfe_values.append(mfe)
        writer.writerow([f"sequence_{i}", seq, structure, mfe])
