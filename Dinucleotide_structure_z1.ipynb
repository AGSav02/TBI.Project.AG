# %%
import csv
import RNA
import varnaapi

input_tsv = "/scr/velara/bioinf2/TBI.Project.AG/dinucleotide_zscores_z1_out.tsv"
output_tsv = "dinucleotide_z1_structure.tsv"

with open(input_tsv, "r") as infile, open(output_tsv, "w", newline="") as outfile:
    reader = csv.reader(infile, delimiter="\t")
    writer = csv.writer(outfile, delimiter="\t")

    header = next(reader)

    new_header = [header[1], header[2], "structure", header[0]]
    writer.writerow(new_header)

    for line_number, row in enumerate(reader, start=2):
        if not row:
            continue

        sequence = row[0]
        col2 = row[1]  
        zscore = row[2]

        fc = RNA.fold_compound(sequence)
        structure, _mfe_ignored = fc.mfe()  

        new_row = [col2, zscore, structure, sequence]
        writer.writerow(new_row)

        v = Structure(sequence=sequence, structure=structure)
        v.show()   

        print(f"[Line {line_number}] Sequence: {sequence}")
# Out:
# Output file: /tmp/tmpdu_f864h.svg
# ...

# %%
import csv
import RNA
import varnaapi

input_tsv = "/scr/velara/bioinf2/TBI.Project.AG/dinucleotide_zscores_z3_out.tsv"
output_tsv = "dinucleotide_z3_structure.tsv"

with open(input_tsv, "r") as infile, open(output_tsv, "w", newline="") as outfile:
    reader = csv.reader(infile, delimiter="\t")
    writer = csv.writer(outfile, delimiter="\t")

    header = next(reader)

    new_header = [header[1], header[2], "structure", header[0]]
    writer.writerow(new_header)

    for line_number, row in enumerate(reader, start=2):
        if not row:
            continue

        sequence = row[0]
        col2 = row[1]  
        zscore = row[2]

        fc = RNA.fold_compound(sequence)
        structure, _mfe_ignored = fc.mfe()  

        new_row = [col2, zscore, structure, sequence]
        writer.writerow(new_row)

        v = Structure(sequence=sequence, structure=structure)
        v.show()   

        print(f"[Line {line_number}] Sequence: {sequence}")
# Out:
# Output file: /tmp/tmpxjrzo_u2.svg
# ...

# %%
import csv
import RNA
import varnaapi

input_tsv = "/scr/velara/bioinf2/TBI.Project.AG/dinucleotide_zscores_z5_out.tsv"
output_tsv = "dinucleotide_z5_structure.tsv"

with open(input_tsv, "r") as infile, open(output_tsv, "w", newline="") as outfile:
    reader = csv.reader(infile, delimiter="\t")
    writer = csv.writer(outfile, delimiter="\t")

    header = next(reader)

    new_header = [header[1], header[2], "structure", header[0]]
    writer.writerow(new_header)

    for line_number, row in enumerate(reader, start=2):
        if not row:
            continue

        sequence = row[0]
        col2 = row[1]  
        zscore = row[2]

        fc = RNA.fold_compound(sequence)
        structure, _mfe_ignored = fc.mfe()  

        new_row = [col2, zscore, structure, sequence]
        writer.writerow(new_row)

        v = Structure(sequence=sequence, structure=structure)
        v.show()   

        print(f"[Line {line_number}] Sequence: {sequence}")
# Out:
# Output file: /tmp/tmph5pbxbd8.svg
# ...
